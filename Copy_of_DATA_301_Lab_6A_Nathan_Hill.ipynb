# %% [markdown]
# # CityBikes Rest API
#
# This section asks you to fetch JSON data from the [CityBikes REST API](https://api.citybik.es/v2/) to answer some questions about bike share programs.
#
# Please be mindful not to send requests to the server more often than necessary. In particular, make sure you separate code that requests data from the server into a separate cell so that you do not have to repeatedly request data from the server. You will lose points if your requests are not separated into their own cell.

# %%
import requests
response = requests.get("http://api.citybik.es/v2/networks")

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

#print(response.text[:1000])
data_bikes = response.json()
bikes = data_bikes["networks"]
bikes[0]
df_bikes = json_normalize(bikes)
df_bikes.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                           company  ... license.url
# 0                [ЗАО «СитиБайк»]  ...         NaN
# 1                    [Gobike A/S]  ...         NaN
# 2                    [Gobike A/S]  ...         NaN
# 3  [Urban Infrastructure Partner]  ...         NaN
# 4                    [Gobike A/S]  ...         NaN
#
# [5 rows x 12 columns]

# %% [markdown]
# # Question 1
#
# Find all cities with bike share programs in the United States (country code "US"), along with their network ID (for example, "ford-gobike"). How many cities in the U.S. have bike share programs (at least that are in this API)?

# %%
us = df_bikes[df_bikes["location.country"] == "US"]
len(us["id"].unique())
# Out:
# 64

# %% [markdown]
# # Question 2
#
# Construct a `DataFrame` containing data about all bike stations in all networks in the United States. Save this `DataFrame` to disk using `.to_csv()`. (You will need it in Part B of this lab.)
#
# Use this `DataFrame` to determine the total number of bicycles in bike share programs across the United States? You may assume that the number of bikes at a station is the number of empty spaces, plus the number of available bikes.

# %%
import time

df_us = []
df_stations = []
for x in range(0,64):
    network_id = us["id"].iloc[x]
    response = requests.get("http://api.citybik.es/v2/networks/%s" % network_id)
    data_bikes = response.json()
    bikes = data_bikes["network"]
    df_stations.append(json_normalize(bikes, "stations", meta="name", meta_prefix="network."))
    df_us.append(json_normalize(bikes))
    time.sleep(0.499)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
bikes
# Out:
# {'company': ['Motivate LLC'],
#  'gbfs_href': 'https://gbfs.baywheels.com/gbfs/gbfs.json',
#  'href': '/v2/networks/bay-wheels',
#  'id': 'bay-wheels',
#  'location': {'city': 'San Francisco Bay Area, CA',
#   'country': 'US',
#   'latitude': 37.7141454,
#   'longitude': -122.25},
#  'name': 'Bay Wheels',
#  'stations': [{'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645574501,
#     'renting': 1,
#     'returning': 1,
#     'uid': '340'},
#    'free_bikes': 5,
#    'id': 'd0e8f4f1834b7b33a3faf8882f567ab8',
#    'latitude': 37.849735,
#    'longitude': -122.270582,
#    'name': 'Harmon St at Adeline St',
#    'timestamp': '2022-02-23T03:54:22.093000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532780,
#     'renting': 1,
#     'returning': 1,
#     'uid': '341'},
#    'free_bikes': 6,
#    'id': '983514094dd808b1604da2dcfc2d09af',
#    'latitude': 37.33618830029063,
#    'longitude': -121.88927650451659,
#    'name': 'Fountain Alley at S 2nd St',
#    'timestamp': '2022-02-23T03:54:22.096000Z'},
#   {'empty_slots': 3,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645578791,
#     'renting': 1,
#     'returning': 1,
#     'uid': '298'},
#    'free_bikes': 20,
#    'id': 'da17603652106fda93da4e255a5b0a22',
#    'latitude': 37.322124625448566,
#    'longitude': -121.88109040260315,
#    'name': 'Oak St at 1st St',
#    'timestamp': '2022-02-23T03:54:22.100000Z'},
#   {'empty_slots': 2,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532479,
#     'renting': 1,
#     'returning': 1,
#     'uid': '299'},
#    'free_bikes': 13,
#    'id': '7a21c92b3b4cd2f7759107b4fdebf869',
#    'latitude': 37.3236779,
#    'longitude': -121.8741186,
#    'name': 'Bestor Art Park',
#    'timestamp': '2022-02-23T03:54:22.101000Z'},
#   {'empty_slots': 22,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645574108,
#     'renting': 1,
#     'returning': 1,
#     'uid': '296'},
#    'free_bikes': 5,
#    'id': 'ce34d38fb230a23c1ced12d1e16df294',
#    'latitude': 37.3259984,
#    'longitude': -121.87712,
#    'name': '5th St at Virginia St',
#    'timestamp': '2022-02-23T03:54:22.106000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532178,
#     'renting': 1,
#     'returning': 1,
#     'uid': '297'},
#    'free_bikes': 4,
#    'id': 'a3b487ad4ac93ab3e9f9654f87ed8c1e',
#    'latitude': 37.3229796,
#    'longitude': -121.8879312,
#    'name': 'Locust St at Grant St',
#    'timestamp': '2022-02-23T03:54:22.107000Z'},
#   {'empty_slots': 7,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645566100,
#     'renting': 1,
#     'returning': 1,
#     'uid': '294'},
#    'free_bikes': 20,
#    'id': 'b4b0088fb4fbb4587cad9d89ddc092cd',
#    'latitude': 37.327581,
#    'longitude': -121.884559,
#    'name': 'Pierce Ave at Market St',
#    'timestamp': '2022-02-23T03:54:22.114000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532479,
#     'renting': 1,
#     'returning': 1,
#     'uid': '295'},
#    'free_bikes': 17,
#    'id': 'd576652cc151c23d6ec52b8454429d47',
#    'latitude': 37.3327938,
#    'longitude': -121.8759263,
#    'name': 'William St at 10th St',
#    'timestamp': '2022-02-23T03:54:22.126000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583314,
#     'renting': 1,
#     'returning': 1,
#     'uid': '292'},
#    'free_bikes': 2,
#    'id': '0a24b6ab9ca6684780b6682901b3c680',
#    'latitude': 37.3448821,
#    'longitude': -121.8969655,
#    'name': 'Empire St at 1st St',
#    'timestamp': '2022-02-23T03:54:22.127000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582322,
#     'renting': 1,
#     'returning': 1,
#     'uid': '291'},
#    'free_bikes': 11,
#    'id': 'a4b234ab072402cbfcbd5e306588d9a9',
#    'latitude': 37.3413348,
#    'longitude': -121.9031829,
#    'name': 'Autumn Parkway at Coleman Ave',
#    'timestamp': '2022-02-23T03:54:22.140000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587093,
#     'renting': 1,
#     'returning': 1,
#     'uid': '198'},
#    'free_bikes': 19,
#    'id': 'c7d58812e5bcf9183e20ec387d0386a9',
#    'latitude': 37.80781318217903,
#    'longitude': -122.26449608802795,
#    'name': 'Snow Park',
#    'timestamp': '2022-02-23T03:54:22.141000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587916,
#     'renting': 1,
#     'returning': 1,
#     'uid': '195'},
#    'free_bikes': 10,
#    'id': 'd030365db7e396de64147261e783a062',
#    'latitude': 37.81231409135146,
#    'longitude': -122.26077854633331,
#    'name': 'Bay Pl at Vernon St',
#    'timestamp': '2022-02-23T03:54:22.148000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583425,
#     'renting': 1,
#     'returning': 1,
#     'uid': '194'},
#    'free_bikes': 9,
#    'id': 'ade8fb7d8bab829cc6b2b752c02882ff',
#    'latitude': 37.8110807,
#    'longitude': -122.2432677,
#    'name': 'Lakeshore Ave at Trestle Glen Rd',
#    'timestamp': '2022-02-23T03:54:22.149000Z'},
#   {'empty_slots': 3,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586232,
#     'renting': 1,
#     'returning': 1,
#     'uid': '196'},
#    'free_bikes': 20,
#    'id': '3a9baba8738c921ad820add914d8d365',
#    'latitude': 37.80889393398715,
#    'longitude': -122.25646018981932,
#    'name': 'Grand Ave at Perkins St',
#    'timestamp': '2022-02-23T03:54:22.164000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585474,
#     'renting': 1,
#     'returning': 1,
#     'uid': '191'},
#    'free_bikes': 3,
#    'id': '8870d1c76fa018d1758fad83f2be5237',
#    'latitude': 37.8305452,
#    'longitude': -122.2739367,
#    'name': 'Market St at 40th St',
#    'timestamp': '2022-02-23T03:54:22.173000Z'},
#   {'empty_slots': 21,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645553189,
#     'renting': 1,
#     'returning': 1,
#     'uid': '190'},
#    'free_bikes': 2,
#    'id': 'a840a66dcf537eb53ff86c7ed469f491',
#    'latitude': 37.8302232,
#    'longitude': -122.2709501,
#    'name': 'West St at 40th St',
#    'timestamp': '2022-02-23T03:54:22.174000Z'},
#   {'empty_slots': 2,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645578514,
#     'renting': 1,
#     'returning': 1,
#     'uid': '193'},
#    'free_bikes': 17,
#    'id': '315bd655b7cf06f4cf2e3c78879043e4',
#    'latitude': 37.8127441,
#    'longitude': -122.2472152,
#    'name': 'Grand Ave at Santa Clara Ave',
#    'timestamp': '2022-02-23T03:54:22.180000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645581448,
#     'renting': 1,
#     'returning': 1,
#     'uid': '271'},
#    'free_bikes': 6,
#    'id': 'c58c5e00d5caeb09fab3509a349ac2ce',
#    'latitude': 37.85578332030199,
#    'longitude': -122.28312671184538,
#    'name': 'San Pablo Park',
#    'timestamp': '2022-02-23T03:54:22.217000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645573287,
#     'renting': 1,
#     'returning': 1,
#     'uid': '273'},
#    'free_bikes': 9,
#    'id': '55389695e3090fea977edbe85a0b7dfc',
#    'latitude': 37.855573661828785,
#    'longitude': -122.26356536149979,
#    'name': 'Fulton St at Ashby Ave',
#    'timestamp': '2022-02-23T03:54:22.240000Z'},
#   {'empty_slots': 9,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585745,
#     'renting': 1,
#     'returning': 1,
#     'uid': '274'},
#    'free_bikes': 11,
#    'id': '81cc789c1070340c1930450769536ea2',
#    'latitude': 37.8575672,
#    'longitude': -122.2675583,
#    'name': 'Oregon St at Adeline St',
#    'timestamp': '2022-02-23T03:54:22.257000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645559412,
#     'renting': 1,
#     'returning': 1,
#     'uid': '275'},
#    'free_bikes': 1,
#    'id': '155125eff6270d14ae62b26c85f15ce3',
#    'latitude': 37.3429973,
#    'longitude': -121.8888891,
#    'name': 'Julian St at 6th St',
#    'timestamp': '2022-02-23T03:54:22.268000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582792,
#     'renting': 1,
#     'returning': 1,
#     'uid': '276'},
#    'free_bikes': 10,
#    'id': '2bef6d41ec5018bb81726f3e1f59d344',
#    'latitude': 37.3322326,
#    'longitude': -121.9125165,
#    'name': 'Julian St at The Alameda',
#    'timestamp': '2022-02-23T03:54:22.269000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645571384,
#     'renting': 1,
#     'returning': 1,
#     'uid': '278'},
#    'free_bikes': 10,
#    'id': '98374aab7a1553d232630758717d87a7',
#    'latitude': 37.3319323,
#    'longitude': -121.9048882,
#    'name': 'The Alameda at Bush St',
#    'timestamp': '2022-02-23T03:54:22.271000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587311,
#     'renting': 1,
#     'returning': 1,
#     'uid': '279'},
#    'free_bikes': 5,
#    'id': 'ead93e0002db0611076fb2d63f76ce05',
#    'latitude': 37.3391456,
#    'longitude': -121.8841054,
#    'name': 'Santa Clara St at 7th St',
#    'timestamp': '2022-02-23T03:54:22.276000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533083,
#     'renting': 1,
#     'returning': 1,
#     'uid': '443'},
#    'free_bikes': 6,
#    'id': '3b360d106be2aeada021d0498be74fd5',
#    'latitude': 37.32086614588923,
#    'longitude': -121.87627851963045,
#    'name': '3rd St at Keyes St',
#    'timestamp': '2022-02-23T03:54:22.307000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645587476,
#     'renting': 1,
#     'returning': 1,
#     'uid': '107'},
#    'free_bikes': 9,
#    'id': '62e21ee5590d59c9e7d740bf16a06bd3',
#    'latitude': 37.7630152,
#    'longitude': -122.4264968,
#    'name': '17th St at Dolores St',
#    'timestamp': '2022-02-23T03:54:22.360000Z'},
#   {'empty_slots': 33,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645585075,
#     'renting': 1,
#     'returning': 1,
#     'uid': '104'},
#    'free_bikes': 2,
#    'id': '2b14980ea8a5986da568e3711ef9cf95',
#    'latitude': 37.76704457969368,
#    'longitude': -122.39083349704742,
#    'name': '4th St at 16th St',
#    'timestamp': '2022-02-23T03:54:22.362000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 7,
#     'has_ebikes': True,
#     'last_updated': 1645587064,
#     'renting': 1,
#     'returning': 1,
#     'uid': '39'},
#    'free_bikes': 21,
#    'id': 'b2247b6dec3a4c153f9f983b2e36534b',
#    'latitude': 37.7789994,
#    'longitude': -122.4368608,
#    'name': 'Scott St at Golden Gate Ave',
#    'timestamp': '2022-02-23T03:54:22.376000Z'},
#   {'empty_slots': 23,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645587033,
#     'renting': 1,
#     'returning': 1,
#     'uid': '36'},
#    'free_bikes': 12,
#    'id': '147b91431e228c6275b040c2cd4d05aa',
#    'latitude': 37.78383,
#    'longitude': -122.39887,
#    'name': 'Folsom St at 3rd St',
#    'timestamp': '2022-02-23T03:54:22.390000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645584938,
#     'renting': 1,
#     'returning': 1,
#     'uid': '35'},
#    'free_bikes': 10,
#    'id': '2e148870409210e664005a58263b186a',
#    'latitude': 37.32911866814779,
#    'longitude': -121.90457582473755,
#    'name': 'Cahill Park',
#    'timestamp': '2022-02-23T03:54:22.391000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645569095,
#     'renting': 1,
#     'returning': 1,
#     'uid': '433'},
#    'free_bikes': 3,
#    'id': '3cfc266f34c8daf3fa59119deca078ea',
#    'latitude': 37.7316566899845,
#    'longitude': -122.45112150907515,
#    'name': 'Gennessee St at Monterey Blvd',
#    'timestamp': '2022-02-23T03:54:22.424000Z'},
#   {'empty_slots': 1,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645559247,
#     'renting': 1,
#     'returning': 1,
#     'uid': '339'},
#    'free_bikes': 26,
#    'id': 'b1385ff2e23b82e61c668a9fc8275142',
#    'latitude': 37.80000163118878,
#    'longitude': -122.26643800735472,
#    'name': 'Jackson St at 11th St',
#    'timestamp': '2022-02-23T03:54:22.428000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645588273,
#     'renting': 1,
#     'returning': 1,
#     'uid': '338'},
#    'free_bikes': 15,
#    'id': 'f31b0518ca63295746f5a85c5540ed96',
#    'latitude': 37.80318908113163,
#    'longitude': -122.27057933807373,
#    'name': '13th St at Franklin St',
#    'timestamp': '2022-02-23T03:54:22.438000Z'},
#   {'empty_slots': 25,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645581831,
#     'renting': 1,
#     'returning': 1,
#     'uid': '337'},
#    'free_bikes': 2,
#    'id': '0dea2fc1c8cc19369db493d2278fbbbc',
#    'latitude': 37.80696976095594,
#    'longitude': -122.26658821105957,
#    'name': 'Webster St at 19th St',
#    'timestamp': '2022-02-23T03:54:22.448000Z'},
#   {'empty_slots': 23,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587286,
#     'renting': 1,
#     'returning': 1,
#     'uid': '6'},
#    'free_bikes': 0,
#    'id': '28754859653e0a656ba53e1fa0ea21db',
#    'latitude': 37.80477,
#    'longitude': -122.403234,
#    'name': 'The Embarcadero at Sansome St',
#    'timestamp': '2022-02-23T03:54:22.458000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645587399,
#     'renting': 1,
#     'returning': 1,
#     'uid': '91'},
#    'free_bikes': 12,
#    'id': 'eb9c95aaf839b9c7e8b18e68288862a3',
#    'latitude': 37.771762110313176,
#    'longitude': -122.39843755960464,
#    'name': 'Berry St at King St',
#    'timestamp': '2022-02-23T03:54:22.478000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645587257,
#     'renting': 1,
#     'returning': 1,
#     'uid': '90'},
#    'free_bikes': 11,
#    'id': 'd057730bd39a7e2c920ff32d19393eb6',
#    'latitude': 37.771058,
#    'longitude': -122.402717,
#    'name': 'Townsend St at 7th St',
#    'timestamp': '2022-02-23T03:54:22.483000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645587884,
#     'renting': 1,
#     'returning': 1,
#     'uid': '92'},
#    'free_bikes': 17,
#    'id': 'bafbf8c2ef10271c489e9ab99dc9bd21',
#    'latitude': 37.772300631747626,
#    'longitude': -122.39302754402159,
#    'name': 'Mission Bay Kids Park',
#    'timestamp': '2022-02-23T03:54:22.491000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645587728,
#     'renting': 1,
#     'returning': 1,
#     'uid': '95'},
#    'free_bikes': 7,
#    'id': '2c505c45b2e849f1523a243b73a34daf',
#    'latitude': 37.7662185,
#    'longitude': -122.4310597,
#    'name': 'Sanchez St at 15th St',
#    'timestamp': '2022-02-23T03:54:22.497000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645588379,
#     'renting': 1,
#     'returning': 1,
#     'uid': '238'},
#    'free_bikes': 3,
#    'id': '840924c8e286486604f62ef9c02ef185',
#    'latitude': 37.8717192,
#    'longitude': -122.2730677,
#    'name': 'MLK Jr Way at University Ave',
#    'timestamp': '2022-02-23T03:54:22.514000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645576132,
#     'renting': 1,
#     'returning': 1,
#     'uid': '234'},
#    'free_bikes': 6,
#    'id': '9aabe0cff5a5e7c6b014dd2c163f1ebc',
#    'latitude': 37.778058,
#    'longitude': -122.2254,
#    'name': 'Farnam St at Fruitvale Ave',
#    'timestamp': '2022-02-23T03:54:22.519000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645531877,
#     'renting': 1,
#     'returning': 1,
#     'uid': '235'},
#    'free_bikes': 13,
#    'id': '6990760eb8be3fa93313672d7be369e6',
#    'latitude': 37.8072393,
#    'longitude': -122.2893702,
#    'name': 'Union St at 10th St',
#    'timestamp': '2022-02-23T03:54:22.520000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587430,
#     'renting': 1,
#     'returning': 1,
#     'uid': '236'},
#    'free_bikes': 4,
#    'id': '2320b4d9a10404fc609ec18aecbd07e8',
#    'latitude': 37.8036865,
#    'longitude': -122.282497,
#    'name': 'Market St at 8th St',
#    'timestamp': '2022-02-23T03:54:22.524000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645581654,
#     'renting': 1,
#     'returning': 1,
#     'uid': '237'},
#    'free_bikes': 2,
#    'id': '55f0ed0965a5a80f451700832338cd49',
#    'latitude': 37.7752321,
#    'longitude': -122.2244982,
#    'name': 'Fruitvale BART Station',
#    'timestamp': '2022-02-23T03:54:22.526000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533683,
#     'renting': 1,
#     'returning': 1,
#     'uid': '231'},
#    'free_bikes': 15,
#    'id': '726e22d3f8e5b2f3b21230c49aa676c8',
#    'latitude': 37.80874983465997,
#    'longitude': -122.28328227996825,
#    'name': '14th St at Filbert St',
#    'timestamp': '2022-02-23T03:54:22.534000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645584828,
#     'renting': 1,
#     'returning': 1,
#     'uid': '232'},
#    'free_bikes': 7,
#    'id': 'bd6bf51c4defa1eba0c9bdbc8478b3ce',
#    'latitude': 37.8061628,
#    'longitude': -122.2760402,
#    'name': 'MLK Jr Way at 14th St',
#    'timestamp': '2022-02-23T03:54:22.536000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645588365,
#     'renting': 1,
#     'returning': 1,
#     'uid': '147'},
#    'free_bikes': 15,
#    'id': 'c0c37f106fa8f27da58b777b7681f9a8',
#    'latitude': 37.7440667,
#    'longitude': -122.4214722,
#    'name': '29th St at Tiffany Ave',
#    'timestamp': '2022-02-23T03:54:22.546000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645585743,
#     'renting': 1,
#     'returning': 1,
#     'uid': '144'},
#    'free_bikes': 7,
#    'id': '446009f5d7c3932df1a0215e04df9891',
#    'latitude': 37.7472996,
#    'longitude': -122.4114029,
#    'name': 'Precita Park',
#    'timestamp': '2022-02-23T03:54:22.547000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645582849,
#     'renting': 1,
#     'returning': 1,
#     'uid': '145'},
#    'free_bikes': 4,
#    'id': 'caee8a5f24d36ec088093ba35c67492d',
#    'latitude': 37.7436839,
#    'longitude': -122.4268059,
#    'name': '29th St at Church St',
#    'timestamp': '2022-02-23T03:54:22.548000Z'},
#   {'empty_slots': 9,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645586997,
#     'renting': 1,
#     'returning': 1,
#     'uid': '142'},
#    'free_bikes': 6,
#    'id': 'bafd382d63b84005dec3dcfc5a326e98',
#    'latitude': 37.745738796183325,
#    'longitude': -122.42214024066925,
#    'name': 'Guerrero Park',
#    'timestamp': '2022-02-23T03:54:22.561000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586268,
#     'renting': 1,
#     'returning': 1,
#     'uid': '140'},
#    'free_bikes': 4,
#    'id': 'd63f2433c8e67e0db4df7a87e5fb38e3',
#    'latitude': 37.7478584,
#    'longitude': -122.4249863,
#    'name': 'Cesar Chavez St at Dolores St',
#    'timestamp': '2022-02-23T03:54:22.562000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645573336,
#     'renting': 1,
#     'returning': 1,
#     'uid': '148'},
#    'free_bikes': 9,
#    'id': '5a3ef6c03f1ce19c588c078270170a18',
#    'latitude': 37.8297046,
#    'longitude': -122.2876102,
#    'name': 'Horton St at 40th St',
#    'timestamp': '2022-02-23T03:54:22.576000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645544927,
#     'renting': 1,
#     'returning': 1,
#     'uid': '149'},
#    'free_bikes': 10,
#    'id': '7e709245031d51963a79004362950401',
#    'latitude': 37.8312752,
#    'longitude': -122.2856333,
#    'name': 'Emeryville Town Hall',
#    'timestamp': '2022-02-23T03:54:22.577000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 13,
#     'has_ebikes': True,
#     'last_updated': 1645587840,
#     'renting': 1,
#     'returning': 1,
#     'uid': '133'},
#    'free_bikes': 16,
#    'id': 'ad0fd1e1100453a35d7ce5e5d95e4779',
#    'latitude': 37.7552126,
#    'longitude': -122.4209752,
#    'name': 'Valencia St at 22nd St',
#    'timestamp': '2022-02-23T03:54:22.578000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 9,
#     'has_ebikes': True,
#     'last_updated': 1645586719,
#     'renting': 1,
#     'returning': 1,
#     'uid': '132'},
#    'free_bikes': 13,
#    'id': 'd54612ee1577923ef1aef60393aa07c7',
#    'latitude': 37.7518194,
#    'longitude': -122.4266139,
#    'name': '24th St at Chattanooga St',
#    'timestamp': '2022-02-23T03:54:22.579000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645587937,
#     'renting': 1,
#     'returning': 1,
#     'uid': '134'},
#    'free_bikes': 15,
#    'id': '689893116ddb1b8dfab61c092330b00a',
#    'latitude': 37.7524278,
#    'longitude': -122.4206278,
#    'name': 'Valencia St at 24th St',
#    'timestamp': '2022-02-23T03:54:22.591000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 11,
#     'has_ebikes': True,
#     'last_updated': 1645580890,
#     'renting': 1,
#     'returning': 1,
#     'uid': '138'},
#    'free_bikes': 14,
#    'id': '96bae776dd2cf75e6ed06895761636af',
#    'latitude': 37.7509004,
#    'longitude': -122.4274114,
#    'name': 'Jersey St at Church St',
#    'timestamp': '2022-02-23T03:54:22.595000Z'},
#   {'empty_slots': 18,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645588321,
#     'renting': 1,
#     'returning': 1,
#     'uid': '26'},
#    'free_bikes': 5,
#    'id': '22e24861b62c61aa3c99d47cd90095ce',
#    'latitude': 37.78729,
#    'longitude': -122.39438,
#    'name': '1st St at Folsom St',
#    'timestamp': '2022-02-23T03:54:22.608000Z'},
#   {'empty_slots': 1,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645587963,
#     'renting': 1,
#     'returning': 1,
#     'uid': '20'},
#    'free_bikes': 20,
#    'id': 'a536696bbab818af37342ac705d5b467',
#    'latitude': 37.7913,
#    'longitude': -122.399051,
#    'name': 'Mechanics Monument Plaza (Market St at Bush St)',
#    'timestamp': '2022-02-23T03:54:22.617000Z'},
#   {'empty_slots': 24,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645580199,
#     'renting': 1,
#     'returning': 1,
#     'uid': '29'},
#    'free_bikes': 3,
#    'id': 'cbe0501b53945e1a590ff4484798e0e6',
#    'latitude': 37.782404601934104,
#    'longitude': -122.43944585323335,
#    'name': "O'Farrell St at Divisadero St",
#    'timestamp': '2022-02-23T03:54:22.623000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645563648,
#     'renting': 1,
#     'returning': 1,
#     'uid': '407'},
#    'free_bikes': 10,
#    'id': '6d5e221de84a938a2a813425ddddcf2d',
#    'latitude': 37.31515792998312,
#    'longitude': -121.89783275127412,
#    'name': 'Bird Ave at Coe Ave',
#    'timestamp': '2022-02-23T03:54:22.624000Z'},
#   {'empty_slots': 22,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645533082,
#     'renting': 1,
#     'returning': 1,
#     'uid': '406'},
#    'free_bikes': 5,
#    'id': '679621279b937eda9558ca1ae02f748e',
#    'latitude': 37.316736478493425,
#    'longitude': -121.91000461578369,
#    'name': 'Parkmoor Ave at Race St',
#    'timestamp': '2022-02-23T03:54:22.631000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585165,
#     'renting': 1,
#     'returning': 1,
#     'uid': '405'},
#    'free_bikes': 8,
#    'id': '10880ce63c335b9192ecf58992798f23',
#    'latitude': 37.32345133870681,
#    'longitude': -121.90597593784332,
#    'name': 'Sunol St at San Carlos St',
#    'timestamp': '2022-02-23T03:54:22.632000Z'},
#   {'empty_slots': 7,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533082,
#     'renting': 1,
#     'returning': 1,
#     'uid': '404'},
#    'free_bikes': 12,
#    'id': 'b16dd2738997ef81f15f2822ce4f8745',
#    'latitude': 37.345758795303155,
#    'longitude': -121.87067806720735,
#    'name': '21st St at Santa Clara St',
#    'timestamp': '2022-02-23T03:54:22.634000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645578773,
#     'renting': 1,
#     'returning': 1,
#     'uid': '402'},
#    'free_bikes': 14,
#    'id': 'f15f772b3686c852122d5d2737bb88a8',
#    'latitude': 37.356834352780886,
#    'longitude': -121.89593575894831,
#    'name': 'Raymond Bernal Jr Memorial Park (8th St at Hedding St)',
#    'timestamp': '2022-02-23T03:54:22.642000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645544181,
#     'renting': 1,
#     'returning': 1,
#     'uid': '401'},
#    'free_bikes': 13,
#    'id': 'aef71869dbbdf150a0e6807bc3512730',
#    'latitude': 37.36522655191025,
#    'longitude': -121.9168147444725,
#    'name': 'Skyport Dr at Technology Dr',
#    'timestamp': '2022-02-23T03:54:22.643000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645562578,
#     'renting': 1,
#     'returning': 1,
#     'uid': '409'},
#    'free_bikes': 13,
#    'id': 'a73276ab34067c112ab469c5107e1d2c',
#    'latitude': 37.83954308266563,
#    'longitude': -122.2987177222967,
#    'name': '2100 Powell St',
#    'timestamp': '2022-02-23T03:54:22.645000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645588085,
#     'renting': 1,
#     'returning': 1,
#     'uid': '370'},
#    'free_bikes': 4,
#    'id': 'ccfc6870981cdd44b5a41bdee14e2a40',
#    'latitude': 37.7873267660624,
#    'longitude': -122.41327822208405,
#    'name': 'Jones St at Post St',
#    'timestamp': '2022-02-23T03:54:22.649000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 6,
#     'has_ebikes': True,
#     'last_updated': 1645587453,
#     'renting': 1,
#     'returning': 1,
#     'uid': '373'},
#    'free_bikes': 13,
#    'id': '35ecc8b9ed527420e102f4f1254583b2',
#    'latitude': 37.75179164525661,
#    'longitude': -122.40521550178528,
#    'name': 'Potrero del Sol Park (25th St at Utah St)',
#    'timestamp': '2022-02-23T03:54:22.652000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645562957,
#     'renting': 1,
#     'returning': 1,
#     'uid': '372'},
#    'free_bikes': 5,
#    'id': 'e1217bf29c178d096c6e92ea8dc36453',
#    'latitude': 37.804036784023594,
#    'longitude': -122.26240932941435,
#    'name': 'Madison St at 17th St',
#    'timestamp': '2022-02-23T03:54:22.653000Z'},
#   {'empty_slots': 0,
#    'extra': {'address': None,
#     'ebikes': 4,
#     'has_ebikes': True,
#     'last_updated': 1645566768,
#     'renting': 1,
#     'returning': 1,
#     'uid': '392'},
#    'free_bikes': 15,
#    'id': '8924b980effba05ac4610a4abd37839e',
#    'latitude': 37.364060462258806,
#    'longitude': -121.9117319583893,
#    'name': 'Sonora Ave at 1st St',
#    'timestamp': '2022-02-23T03:54:22.674000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 4,
#     'has_ebikes': True,
#     'last_updated': 1645584330,
#     'renting': 1,
#     'returning': 1,
#     'uid': '88'},
#    'free_bikes': 10,
#    'id': '718cefa9c37e218744ea0cc193a3129a',
#    'latitude': 37.7700298,
#    'longitude': -122.4117258,
#    'name': '11th St at Bryant St',
#    'timestamp': '2022-02-23T03:54:22.675000Z'},
#   {'empty_slots': 9,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645575022,
#     'renting': 1,
#     'returning': 1,
#     'uid': '397'},
#    'free_bikes': 14,
#    'id': '9beee70db0437cf4bd24078239213bb6',
#    'latitude': 37.36186680025918,
#    'longitude': -121.90931528806688,
#    'name': 'Gish Rd at 1st St',
#    'timestamp': '2022-02-23T03:54:22.677000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 6,
#     'has_ebikes': True,
#     'last_updated': 1645552016,
#     'renting': 1,
#     'returning': 1,
#     'uid': '396'},
#    'free_bikes': 15,
#    'id': 'ed898b7f32d290732a31b0b519c1f7e3',
#    'latitude': 37.36767805240811,
#    'longitude': -121.9187942147255,
#    'name': 'Metro Dr at Technology Dr',
#    'timestamp': '2022-02-23T03:54:22.678000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533082,
#     'renting': 1,
#     'returning': 1,
#     'uid': '395'},
#    'free_bikes': 17,
#    'id': '219cc838b24b5ceb39af7bcd6e6c5e13',
#    'latitude': 37.360854155253826,
#    'longitude': -121.90683424472809,
#    'name': 'Kerley Dr at Rosemary St',
#    'timestamp': '2022-02-23T03:54:22.679000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645581082,
#     'renting': 1,
#     'returning': 1,
#     'uid': '398'},
#    'free_bikes': 12,
#    'id': '4bbdbdf6abbdbb73cedafe47831eafd1',
#    'latitude': 37.796470691622936,
#    'longitude': -122.4168576300144,
#    'name': 'Leavenworth St at Broadway',
#    'timestamp': '2022-02-23T03:54:22.685000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645584677,
#     'renting': 1,
#     'returning': 1,
#     'uid': '245'},
#    'free_bikes': 15,
#    'id': '0891ec75daf2bf9e823f4a02e21fa9fd',
#    'latitude': 37.870139,
#    'longitude': -122.268422,
#    'name': 'Downtown Berkeley BART',
#    'timestamp': '2022-02-23T03:54:22.697000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583920,
#     'renting': 1,
#     'returning': 1,
#     'uid': '244'},
#    'free_bikes': 3,
#    'id': '193169dbc243a90e9c68e9bd94763748',
#    'latitude': 37.87367621459825,
#    'longitude': -122.26848721504211,
#    'name': 'Shattuck Ave at Hearst Ave',
#    'timestamp': '2022-02-23T03:54:22.698000Z'},
#   {'empty_slots': 7,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587118,
#     'renting': 1,
#     'returning': 1,
#     'uid': '247'},
#    'free_bikes': 16,
#    'id': 'f00345a08621722a4e680cf784706a3c',
#    'latitude': 37.8677892,
#    'longitude': -122.2658964,
#    'name': 'Fulton St at Bancroft Way',
#    'timestamp': '2022-02-23T03:54:22.699000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582933,
#     'renting': 1,
#     'returning': 1,
#     'uid': '246'},
#    'free_bikes': 12,
#    'id': '2367c9313860a8dbae94ac5045768995',
#    'latitude': 37.8690599,
#    'longitude': -122.270556,
#    'name': 'Berkeley Civic Center',
#    'timestamp': '2022-02-23T03:54:22.704000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583954,
#     'renting': 1,
#     'returning': 1,
#     'uid': '241'},
#    'free_bikes': 6,
#    'id': '6230d81b26fbf3b08d04f63a436c69f9',
#    'latitude': 37.8524766,
#    'longitude': -122.2702132,
#    'name': 'Ashby BART Station',
#    'timestamp': '2022-02-23T03:54:22.706000Z'},
#   {'empty_slots': 2,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585570,
#     'renting': 1,
#     'returning': 1,
#     'uid': '240'},
#    'free_bikes': 17,
#    'id': '65097799f269d187692b073a83c0d4d3',
#    'latitude': 37.8660431,
#    'longitude': -122.2588044,
#    'name': 'Haste St at Telegraph Ave',
#    'timestamp': '2022-02-23T03:54:22.707000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586919,
#     'renting': 1,
#     'returning': 1,
#     'uid': '243'},
#    'free_bikes': 15,
#    'id': '47e30e549ebbe3b8fad38f2df2f1ad59',
#    'latitude': 37.8693603,
#    'longitude': -122.2543374,
#    'name': 'Bancroft Way at College Ave',
#    'timestamp': '2022-02-23T03:54:22.710000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645563324,
#     'renting': 1,
#     'returning': 1,
#     'uid': '248'},
#    'free_bikes': 8,
#    'id': 'ca8bbd40ae8b3beb63c5cc63a1c73a0f',
#    'latitude': 37.8559558,
#    'longitude': -122.2597949,
#    'name': 'Telegraph Ave at Ashby Ave',
#    'timestamp': '2022-02-23T03:54:22.716000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582274,
#     'renting': 1,
#     'returning': 1,
#     'uid': '178'},
#    'free_bikes': 3,
#    'id': '1b0c18aa2600cb61c4dc8594a02f4417',
#    'latitude': 37.8193814,
#    'longitude': -122.2619284,
#    'name': 'Broadway at 30th St',
#    'timestamp': '2022-02-23T03:54:22.788000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586645,
#     'renting': 1,
#     'returning': 1,
#     'uid': '177'},
#    'free_bikes': 4,
#    'id': '1ad3234f9bd6b3e93ef20656d9111087',
#    'latitude': 37.8262863,
#    'longitude': -122.2651002,
#    'name': 'MacArthur Blvd at Telegraph Ave',
#    'timestamp': '2022-02-23T03:54:22.789000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645579604,
#     'renting': 1,
#     'returning': 1,
#     'uid': '173'},
#    'free_bikes': 8,
#    'id': 'efbe528107bed4defe202f50c2d6f2c0',
#    'latitude': 37.8403643,
#    'longitude': -122.2644881,
#    'name': 'Shattuck Ave at 55th St',
#    'timestamp': '2022-02-23T03:54:22.795000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645580382,
#     'renting': 1,
#     'returning': 1,
#     'uid': '172'},
#    'free_bikes': 1,
#    'id': 'ab6763b2d94b0eb690addb48b9cf3827',
#    'latitude': 37.8417999,
#    'longitude': -122.2515349,
#    'name': 'College Ave at Taft Ave',
#    'timestamp': '2022-02-23T03:54:22.796000Z'},
#   {'empty_slots': 21,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585199,
#     'renting': 1,
#     'returning': 1,
#     'uid': '171'},
#    'free_bikes': 3,
#    'id': '1e03b246c6716378bd815f00c7a635da',
#    'latitude': 37.84427875399067,
#    'longitude': -122.251900434494,
#    'name': 'Rockridge BART Station',
#    'timestamp': '2022-02-23T03:54:22.797000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645579209,
#     'renting': 1,
#     'returning': 1,
#     'uid': '170'},
#    'free_bikes': 7,
#    'id': '1736d145e5ef5447a53cc9f100701ccc',
#    'latitude': 37.8444927,
#    'longitude': -122.261351,
#    'name': 'Telegraph Ave at 58th St',
#    'timestamp': '2022-02-23T03:54:22.798000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645588249,
#     'renting': 1,
#     'returning': 1,
#     'uid': '183'},
#    'free_bikes': 7,
#    'id': 'edd2cf03bfbe6ade0bd14f40ae4b5ece',
#    'latitude': 37.8087021,
#    'longitude': -122.2699271,
#    'name': 'Telegraph Ave at 19th St',
#    'timestamp': '2022-02-23T03:54:22.804000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645585632,
#     'renting': 1,
#     'returning': 1,
#     'uid': '180'},
#    'free_bikes': 11,
#    'id': 'f54ea4118a93165223d045661a698c74',
#    'latitude': 37.8126783,
#    'longitude': -122.2687726,
#    'name': 'Telegraph Ave at 23rd St',
#    'timestamp': '2022-02-23T03:54:22.806000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582277,
#     'renting': 1,
#     'returning': 1,
#     'uid': '181'},
#    'free_bikes': 11,
#    'id': 'df3ca6be81e340c4899ec6ae8c4429e4',
#    'latitude': 37.8113768,
#    'longitude': -122.2651925,
#    'name': 'Grand Ave at Webster St',
#    'timestamp': '2022-02-23T03:54:22.807000Z'},
#   {'empty_slots': 25,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645581653,
#     'renting': 1,
#     'returning': 1,
#     'uid': '186'},
#    'free_bikes': 2,
#    'id': 'b9afbe24f97e40d2168eed1c8184c07d',
#    'latitude': 37.8013189,
#    'longitude': -122.2626418,
#    'name': 'Lakeside Dr at 14th St',
#    'timestamp': '2022-02-23T03:54:22.812000Z'},
#   {'empty_slots': 3,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645579980,
#     'renting': 1,
#     'returning': 1,
#     'uid': '188'},
#    'free_bikes': 12,
#    'id': '76b57950b5f2a4b0a4821e64bb700e24',
#    'latitude': 37.8426295,
#    'longitude': -122.267738,
#    'name': 'Dover St at 57th St',
#    'timestamp': '2022-02-23T03:54:22.815000Z'},
#   {'empty_slots': 1,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586293,
#     'renting': 1,
#     'returning': 1,
#     'uid': '189'},
#    'free_bikes': 14,
#    'id': 'f848023d531b827a8e7c8c87173b6a4d',
#    'latitude': 37.8396488,
#    'longitude': -122.2717561,
#    'name': 'Genoa St at 55th St',
#    'timestamp': '2022-02-23T03:54:22.816000Z'},
#   {'empty_slots': 25,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645588234,
#     'renting': 1,
#     'returning': 1,
#     'uid': '11'},
#    'free_bikes': 10,
#    'id': 'b735b2cab35ea7bdaff9b2ce7413984f',
#    'latitude': 37.79728,
#    'longitude': -122.398436,
#    'name': 'Davis St at Jackson St',
#    'timestamp': '2022-02-23T03:54:22.817000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 4,
#     'has_ebikes': True,
#     'last_updated': 1645588341,
#     'renting': 1,
#     'returning': 1,
#     'uid': '14'},
#    'free_bikes': 11,
#    'id': 'db937467876feef9bb1695c3ea31779c',
#    'latitude': 37.795001,
#    'longitude': -122.39997,
#    'name': 'Clay St at Battery St',
#    'timestamp': '2022-02-23T03:54:22.826000Z'},
#   {'empty_slots': 10,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645588112,
#     'renting': 1,
#     'returning': 1,
#     'uid': '17'},
#    'free_bikes': 19,
#    'id': 'f64d35757bf16e8af5a408a9c72af91e',
#    'latitude': 37.792251,
#    'longitude': -122.397086,
#    'name': 'Embarcadero BART Station (Beale St at Market St)',
#    'timestamp': '2022-02-23T03:54:22.827000Z'},
#   {'empty_slots': 21,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645588292,
#     'renting': 1,
#     'returning': 1,
#     'uid': '19'},
#    'free_bikes': 14,
#    'id': '6c229502dbd727e48d9b7970dabbd21f',
#    'latitude': 37.788975,
#    'longitude': -122.403452,
#    'name': 'Post St at Kearny St',
#    'timestamp': '2022-02-23T03:54:22.830000Z'},
#   {'empty_slots': 1,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645580777,
#     'renting': 1,
#     'returning': 1,
#     'uid': '18'},
#    'free_bikes': 10,
#    'id': '0794b05a99e808986301411273356796',
#    'latitude': 37.85022187449679,
#    'longitude': -122.26017236709595,
#    'name': 'Telegraph Ave at Alcatraz Ave',
#    'timestamp': '2022-02-23T03:54:22.831000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645544010,
#     'renting': 1,
#     'returning': 1,
#     'uid': '327'},
#    'free_bikes': 2,
#    'id': 'e5a34fd23cbefa6b718d20509d1d8bdc',
#    'latitude': 37.33203868095132,
#    'longitude': -121.8817663192749,
#    'name': '5th St at San Salvador St',
#    'timestamp': '2022-02-23T03:54:22.865000Z'},
#   {'empty_slots': 23,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645587771,
#     'renting': 1,
#     'returning': 1,
#     'uid': '324'},
#    'free_bikes': 4,
#    'id': 'c84aa30b9e135787bd06304d3b4caf88',
#    'latitude': 37.788299978150825,
#    'longitude': -122.40853071212767,
#    'name': 'Union Square (Powell St at Post St)',
#    'timestamp': '2022-02-23T03:54:22.869000Z'},
#   {'empty_slots': 7,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645562188,
#     'renting': 1,
#     'returning': 1,
#     'uid': '202'},
#    'free_bikes': 20,
#    'id': '36aa8ab83177d5f5beb83685c7f645d3',
#    'latitude': 37.8007544,
#    'longitude': -122.2748943,
#    'name': 'Washington St at 8th St',
#    'timestamp': '2022-02-23T03:54:22.890000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645578942,
#     'renting': 1,
#     'returning': 1,
#     'uid': '204'},
#    'free_bikes': 2,
#    'id': 'f83da983e1b1de735ef62006310c76ba',
#    'latitude': 37.8401858,
#    'longitude': -122.2618225,
#    'name': '55th St at Telegraph Ave',
#    'timestamp': '2022-02-23T03:54:22.892000Z'},
#   {'empty_slots': 6,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583956,
#     'renting': 1,
#     'returning': 1,
#     'uid': '207'},
#    'free_bikes': 17,
#    'id': 'ef3a4e5c05845ca17d2c2db654a2a5fa',
#    'latitude': 37.8357883,
#    'longitude': -122.2516207,
#    'name': 'Broadway at Coronado Ave',
#    'timestamp': '2022-02-23T03:54:22.893000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532479,
#     'renting': 1,
#     'returning': 1,
#     'uid': '206'},
#    'free_bikes': 6,
#    'id': 'eea0a9aed0f267d94aa702cd52458754',
#    'latitude': 37.8381269,
#    'longitude': -122.2512714,
#    'name': 'College Ave at Bryant Ave',
#    'timestamp': '2022-02-23T03:54:22.896000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587983,
#     'renting': 1,
#     'returning': 1,
#     'uid': '208'},
#    'free_bikes': 11,
#    'id': '7e64ecd17d4a2708631d979da3ac4443',
#    'latitude': 37.33279952386071,
#    'longitude': -121.88385039567946,
#    'name': '4th St at San Carlos St',
#    'timestamp': '2022-02-23T03:54:22.901000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 6,
#     'has_ebikes': True,
#     'last_updated': 1645578059,
#     'renting': 0,
#     'returning': 0,
#     'uid': '77'},
#    'free_bikes': 15,
#    'id': 'a3e415a5d4437c5b8ed58f5620a2acb1',
#    'latitude': 37.7735069,
#    'longitude': -122.4160402,
#    'name': '11th St at Natoma St',
#    'timestamp': '2022-02-23T03:54:22.902000Z'},
#   {'empty_slots': 24,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586625,
#     'renting': 1,
#     'returning': 1,
#     'uid': '75'},
#    'free_bikes': 11,
#    'id': '25ccddba147690ec254ca9e68d3c559d',
#    'latitude': 37.7737932060887,
#    'longitude': -122.42123901844025,
#    'name': 'Market St at Franklin St',
#    'timestamp': '2022-02-23T03:54:22.912000Z'},
#   {'empty_slots': 22,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645588020,
#     'renting': 1,
#     'returning': 1,
#     'uid': '73'},
#    'free_bikes': 3,
#    'id': 'c7bb5e8c49bf8b8165f0d7f09d620df3',
#    'latitude': 37.7717933,
#    'longitude': -122.4337079,
#    'name': 'Pierce St at Haight St',
#    'timestamp': '2022-02-23T03:54:22.922000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645588410,
#     'renting': 1,
#     'returning': 1,
#     'uid': '71'},
#    'free_bikes': 7,
#    'id': 'e941de3073caf24cb07ee3425c80e479',
#    'latitude': 37.7730627,
#    'longitude': -122.4390777,
#    'name': 'Broderick St at Oak St',
#    'timestamp': '2022-02-23T03:54:22.924000Z'},
#   {'empty_slots': 20,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645580834,
#     'renting': 1,
#     'returning': 1,
#     'uid': '8'},
#    'free_bikes': 3,
#    'id': 'e8ac145be6193651c7de9caf2bece382',
#    'latitude': 37.799953,
#    'longitude': -122.398525,
#    'name': 'The Embarcadero at Vallejo St',
#    'timestamp': '2022-02-23T03:54:22.954000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645587769,
#     'renting': 1,
#     'returning': 1,
#     'uid': '120'},
#    'free_bikes': 10,
#    'id': 'd777960e181c3911183b59171cded0a8',
#    'latitude': 37.7614205,
#    'longitude': -122.4264353,
#    'name': 'Mission Dolores Park',
#    'timestamp': '2022-02-23T03:54:22.962000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645588282,
#     'renting': 1,
#     'returning': 1,
#     'uid': '121'},
#    'free_bikes': 11,
#    'id': '1a07a9e1057626b3844050832a2581bf',
#    'latitude': 37.7592103,
#    'longitude': -122.4213392,
#    'name': 'Mission Playground',
#    'timestamp': '2022-02-23T03:54:22.963000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587461,
#     'renting': 1,
#     'returning': 1,
#     'uid': '123'},
#    'free_bikes': 4,
#    'id': 'd77de46766fff22f98cbfff8959742da',
#    'latitude': 37.7605936,
#    'longitude': -122.4148171,
#    'name': 'Folsom St at 19th St',
#    'timestamp': '2022-02-23T03:54:22.965000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 13,
#     'has_ebikes': True,
#     'last_updated': 1645586423,
#     'renting': 1,
#     'returning': 1,
#     'uid': '126'},
#    'free_bikes': 27,
#    'id': '1a8541216cf020de1dcf4f90c8fd0919',
#    'latitude': 37.7616343,
#    'longitude': -122.3906477,
#    'name': 'Esprit Park',
#    'timestamp': '2022-02-23T03:54:22.976000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645588214,
#     'renting': 1,
#     'returning': 1,
#     'uid': '127'},
#    'free_bikes': 6,
#    'id': 'e8061d928a602d4e74975b184f61df6d',
#    'latitude': 37.7567083,
#    'longitude': -122.421025,
#    'name': 'Valencia St at 21st St',
#    'timestamp': '2022-02-23T03:54:22.977000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645587688,
#     'renting': 1,
#     'returning': 1,
#     'uid': '129'},
#    'free_bikes': 3,
#    'id': 'a861792de6f7790503849a5227a1f8c6',
#    'latitude': 37.758862,
#    'longitude': -122.412544,
#    'name': 'Harrison St at 20th St',
#    'timestamp': '2022-02-23T03:54:22.978000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533081,
#     'renting': 1,
#     'returning': 1,
#     'uid': '415'},
#    'free_bikes': 2,
#    'id': 'b949f871161f40eb2949854a85a0472a',
#    'latitude': 37.31975695999228,
#    'longitude': -121.89299941062927,
#    'name': 'Delmas Ave at Virginia St',
#    'timestamp': '2022-02-23T03:54:22.979000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645552329,
#     'renting': 1,
#     'returning': 1,
#     'uid': '416'},
#    'free_bikes': 4,
#    'id': 'e28f658f5100e41a80d7896d356bc7f6',
#    'latitude': 37.321181834267314,
#    'longitude': -121.9030898809433,
#    'name': 'Auzerais Ave at Los Gatos Creek Trail',
# ...
#    'name': 'Brannan St at Colin P Kelly Jr St',
#    'timestamp': '2022-02-23T03:54:23.199000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645588176,
#     'renting': 1,
#     'returning': 1,
#     'uid': '461'},
#    'free_bikes': 15,
#    'id': 'a1e040b32aa8e99ec1bf2f45df9f21e9',
#    'latitude': 37.7717667,
#    'longitude': -122.3866885,
#    'name': 'Terry Francois Blvd at Mission Bay Blvd N',
#    'timestamp': '2022-02-23T03:54:23.201000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645575988,
#     'renting': 1,
#     'returning': 1,
#     'uid': '167'},
#    'free_bikes': 8,
#    'id': 'ef28178bdcbbd76da0a630ecba6555a5',
#    'latitude': 37.8494355,
#    'longitude': -122.2525406,
#    'name': '62nd St at Claremont Ave',
#    'timestamp': '2022-02-23T03:54:23.210000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645582853,
#     'renting': 1,
#     'returning': 1,
#     'uid': '160'},
#    'free_bikes': 12,
#    'id': '7f25a5477bd79f776a9078c30f768517',
#    'latitude': 37.8051895,
#    'longitude': -122.29461686454057,
#    'name': 'West Oakland BART Station',
#    'timestamp': '2022-02-23T03:54:23.220000Z'},
#   {'empty_slots': 1,
#    'extra': {'address': None,
#     'ebikes': 9,
#     'has_ebikes': True,
#     'last_updated': 1645588238,
#     'renting': 1,
#     'returning': 1,
#     'uid': '356'},
#    'free_bikes': 16,
#    'id': 'fd03c3ceeecfe485dd0cdd8ef72f8e69',
#    'latitude': 37.7690102,
#    'longitude': -122.42224826223539,
#    'name': 'Valencia St at Clinton Park',
#    'timestamp': '2022-02-23T03:54:23.226000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586771,
#     'renting': 1,
#     'returning': 1,
#     'uid': '215'},
#    'free_bikes': 15,
#    'id': 'ded85e8cd7b30115d3ffec9b0777fb50',
#    'latitude': 37.82246767714513,
#    'longitude': -122.26597130298616,
#    'name': '34th St at Telegraph Ave',
#    'timestamp': '2022-02-23T03:54:23.283000Z'},
#   {'empty_slots': 18,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645587339,
#     'renting': 1,
#     'returning': 1,
#     'uid': '282'},
#    'free_bikes': 1,
#    'id': 'c6056f5b51537a2dfd4bf1538444e335',
#    'latitude': 37.324414,
#    'longitude': -121.88078,
#    'name': 'E Virginia St at S 2nd St',
#    'timestamp': '2022-02-23T03:54:23.310000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645532035,
#     'renting': 1,
#     'returning': 1,
#     'uid': '286'},
#    'free_bikes': 0,
#    'id': '0ceed296dc7ef21bc6dc3999e23db576',
#    'latitude': 37.3364659,
#    'longitude': -121.8766132,
#    'name': 'San Carlos St at 11th St',
#    'timestamp': '2022-02-23T03:54:23.318000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645581136,
#     'renting': 1,
#     'returning': 1,
#     'uid': '536'},
#    'free_bikes': 19,
#    'id': '398065f9acb4e27da84e4e78ed3de99c',
#    'latitude': 37.805376,
#    'longitude': -122.437261,
#    'name': 'Fillmore St at Jefferson St',
#    'timestamp': '2022-02-23T03:54:23.352000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645584609,
#     'renting': 1,
#     'returning': 1,
#     'uid': '533'},
#    'free_bikes': 17,
#    'id': '338a6ebbd36aadefe8e02fe32c0cbad0',
#    'latitude': 37.7930958,
#    'longitude': -122.3988357,
#    'name': 'Front St at California St',
#    'timestamp': '2022-02-23T03:54:23.354000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587688,
#     'renting': 1,
#     'returning': 1,
#     'uid': '110'},
#    'free_bikes': 6,
#    'id': '0167c2413c3487d67d1dd7d906389959',
#    'latitude': 37.7637348,
#    'longitude': -122.41552403555308,
#    'name': '17th & Folsom Street Park (17th St at Folsom St)',
#    'timestamp': '2022-02-23T03:54:23.364000Z'},
#   {'empty_slots': 23,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645586943,
#     'renting': 1,
#     'returning': 1,
#     'uid': '47'},
#    'free_bikes': 7,
#    'id': '625d6b7f33c6aec660a79f1afeaf3c30',
#    'latitude': 37.7811944,
#    'longitude': -122.3999862,
#    'name': '4th St at Harrison St',
#    'timestamp': '2022-02-23T03:54:23.433000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645580638,
#     'renting': 1,
#     'returning': 1,
#     'uid': '42'},
#    'free_bikes': 11,
#    'id': '981f5cc5c2c79e96e101c3c20cd56213',
#    'latitude': 37.7788325,
#    'longitude': -122.4181591,
#    'name': 'San Francisco City Hall (Polk St at Grove St)',
#    'timestamp': '2022-02-23T03:54:23.435000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645586147,
#     'renting': 1,
#     'returning': 1,
#     'uid': '43'},
#    'free_bikes': 18,
#    'id': '1a53a1426ed4935f80f5865b7d2d676e',
#    'latitude': 37.778799,
#    'longitude': -122.4159632,
#    'name': 'San Francisco Public Library (Grove St at Hyde St)',
#    'timestamp': '2022-02-23T03:54:23.437000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645533684,
#     'renting': 1,
#     'returning': 1,
#     'uid': '488'},
#    'free_bikes': 5,
#    'id': 'd0a123ad15c1a36560424772600f87dc',
#    'latitude': 37.722601,
#    'longitude': -122.3922705,
#    'name': 'Egbert Ave at Jennings St',
#    'timestamp': '2022-02-23T03:54:23.442000Z'},
#   {'empty_slots': 11,
#    'extra': {'address': None,
#     'ebikes': 8,
#     'has_ebikes': True,
#     'last_updated': 1645587944,
#     'renting': 1,
#     'returning': 1,
#     'uid': '485'},
#    'free_bikes': 16,
#    'id': '4573a1b9377979c07d5ac5ed7556be3e',
#    'latitude': 37.7735636,
#    'longitude': -122.4713658,
#    'name': 'Funston Ave at Fulton St',
#    'timestamp': '2022-02-23T03:54:23.451000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645579770,
#     'renting': 1,
#     'returning': 1,
#     'uid': '475'},
#    'free_bikes': 3,
#    'id': '4a3745a8d75f6261405f5e9a1b5e8f0c',
#    'latitude': 37.3398531,
#    'longitude': -121.8636494,
#    'name': '22nd St at William St',
#    'timestamp': '2022-02-23T03:54:23.464000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 6,
#     'has_ebikes': True,
#     'last_updated': 1645583528,
#     'renting': 1,
#     'returning': 1,
#     'uid': '478'},
#    'free_bikes': 11,
#    'id': '4a766283f8c81155d42781201794fc18',
#    'latitude': 37.80028668467315,
#    'longitude': -122.42578603327274,
#    'name': 'Greenwich St at Franklin St',
#    'timestamp': '2022-02-23T03:54:23.466000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645588255,
#     'renting': 1,
#     'returning': 1,
#     'uid': '479'},
#    'free_bikes': 7,
#    'id': '5edf73914cb05d5a4ba7f03cc573a2e5',
#    'latitude': 37.792979854977766,
#    'longitude': -122.4233016371727,
#    'name': 'Washington St at Van Ness Ave',
#    'timestamp': '2022-02-23T03:54:23.467000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587498,
#     'renting': 1,
#     'returning': 1,
#     'uid': '176'},
#    'free_bikes': 15,
#    'id': 'e7383e730f9fa46419cd5e84fcea3a88',
#    'latitude': 37.8285951,
#    'longitude': -122.2663493,
#    'name': 'MacArthur BART Station',
#    'timestamp': '2022-02-23T03:54:22.790000Z'},
#   {'empty_slots': 2,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645531877,
#     'renting': 1,
#     'returning': 1,
#     'uid': '316'},
#    'free_bikes': 17,
#    'id': '74eca875c15c9468d4dbcece710bc596',
#    'latitude': 37.33116799422201,
#    'longitude': -121.88693761825562,
#    'name': '1st St at San Carlos St',
#    'timestamp': '2022-02-23T03:54:23.129000Z'},
#   {'empty_slots': 12,
#    'extra': {'address': None,
#     'ebikes': 15,
#     'has_ebikes': True,
#     'last_updated': 1645587270,
#     'renting': 1,
#     'returning': 1,
#     'uid': '69'},
#    'free_bikes': 19,
#    'id': 'ad904cefe26dd81e3d48d76b19b768c3',
#    'latitude': 37.7711532,
#    'longitude': -122.4452011,
#    'name': 'Page St at Masonic Ave',
#    'timestamp': '2022-02-23T03:54:23.182000Z'},
#   {'empty_slots': 16,
#    'extra': {'address': None,
#     'ebikes': 2,
#     'has_ebikes': True,
#     'last_updated': 1645585736,
#     'renting': 1,
#     'returning': 1,
#     'uid': '562'},
#    'free_bikes': 9,
#    'id': '78af524c0f2ab327bf75ca1bee9d1e08',
#    'latitude': 37.767256698389865,
#    'longitude': -122.40032913185132,
#    'name': '8th St at Hooper St',
#    'timestamp': '2022-02-23T03:54:23.396000Z'},
#   {'empty_slots': 19,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645587497,
#     'renting': 1,
#     'returning': 1,
#     'uid': '419'},
#    'free_bikes': 1,
#    'id': '700a9ce7584edef750fd2f8481a9c802',
#    'latitude': 37.7870025,
#    'longitude': -122.420053,
#    'name': 'Polk St at Post St',
#    'timestamp': '2022-02-23T03:54:23.097000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583702,
#     'renting': 1,
#     'returning': 1,
#     'uid': '557'},
#    'free_bikes': 5,
#    'id': 'b04f626c4d402aefbecd84d326e5fd55',
#    'latitude': 37.7737524,
#    'longitude': -122.3914274,
#    'name': '4th St at Long Bridge St',
#    'timestamp': '2022-02-23T03:54:22.511000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645582359,
#     'renting': 1,
#     'returning': 1,
#     'uid': '555'},
#    'free_bikes': 10,
#    'id': '5f212a36c28e610e4e579916b4000dfb',
#    'latitude': 37.7971765,
#    'longitude': -122.4036272,
#    'name': 'Montgomery St at Pacific Ave',
#    'timestamp': '2022-02-23T03:54:22.506000Z'},
#   {'empty_slots': 22,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645585322,
#     'renting': 1,
#     'returning': 1,
#     'uid': '558'},
#    'free_bikes': 5,
#    'id': '168084f0f6ef878a07cb0049fd00f52a',
#    'latitude': 37.764783,
#    'longitude': -122.3908972,
#    'name': 'Hospital St at Mariposa St',
#    'timestamp': '2022-02-23T03:54:22.505000Z'},
#   {'empty_slots': 26,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645534710,
#     'renting': 1,
#     'returning': 1,
#     'uid': '523'},
#    'free_bikes': 1,
#    'id': '59d793b5df7d636956033d6eea577230',
#    'latitude': 37.791966,
#    'longitude': -122.429315,
#    'name': 'Lafayette Park (Laguna St at Washington St)',
#    'timestamp': '2022-02-23T03:54:22.288000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 3,
#     'has_ebikes': True,
#     'last_updated': 1645582983,
#     'renting': 1,
#     'returning': 1,
#     'uid': '560'},
#    'free_bikes': 4,
#    'id': 'dfeb123df01f786fe43f8ca3a48938f8',
#    'latitude': 37.768357,
#    'longitude': -122.452862,
#    'name': 'Waller St at Stanyan St',
#    'timestamp': '2022-02-23T03:54:23.393000Z'},
#   {'empty_slots': 15,
#    'extra': {'address': None,
#     'ebikes': 4,
#     'has_ebikes': True,
#     'last_updated': 1645578168,
#     'renting': 1,
#     'returning': 1,
#     'uid': '563'},
#    'free_bikes': 12,
#    'id': 'b815170d0444b1b5cc5f6746d98c31f3',
#    'latitude': 37.7981975,
#    'longitude': -122.4474145,
#    'name': 'Lyon St at Lombard St',
#    'timestamp': '2022-02-23T03:54:23.397000Z'},
#   {'empty_slots': 13,
#    'extra': {'address': None,
#     'ebikes': 14,
#     'has_ebikes': True,
#     'last_updated': 1645585861,
#     'renting': 1,
#     'returning': 1,
#     'uid': '564'},
#    'free_bikes': 14,
#    'id': '8abfd40237f50ff2362082bfe32d8edf',
#    'latitude': 37.788048,
#    'longitude': -122.438812,
#    'name': 'Scott St at California St',
#    'timestamp': '2022-02-23T03:54:23.398000Z'},
#   {'empty_slots': 24,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645584944,
#     'renting': 1,
#     'returning': 1,
#     'uid': '561'},
#    'free_bikes': 11,
#    'id': 'af494e5a9e2088b870da22baaaf0e15b',
#    'latitude': 37.768872,
#    'longitude': -122.3911087,
#    'name': '4th St at Gene Friend Way',
#    'timestamp': '2022-02-23T03:54:23.395000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 12,
#     'has_ebikes': True,
#     'last_updated': 1645581927,
#     'renting': 1,
#     'returning': 1,
#     'uid': '137'},
#    'free_bikes': 14,
#    'id': 'b98c3de69eaf29844c9732daec3d6ff2',
#    'latitude': 37.750506,
#    'longitude': -122.4339496,
#    'name': 'Jersey St at Castro St',
#    'timestamp': '2022-02-23T03:54:22.583000Z'},
#   {'empty_slots': 8,
#    'extra': {'address': None,
#     'ebikes': 1,
#     'has_ebikes': True,
#     'last_updated': 1645577536,
#     'renting': 1,
#     'returning': 1,
#     'uid': '554'},
#    'free_bikes': 11,
#    'id': '51210c5c24903a6525cdfaec38109ec9',
#    'latitude': 37.7965927,
#    'longitude': -122.4556884,
#    'name': 'MacArthur Ave at Fernandez St',
#    'timestamp': '2022-02-23T03:54:22.507000Z'},
#   {'empty_slots': 14,
#    'extra': {'address': None,
#     'ebikes': 6,
#     'has_ebikes': True,
#     'last_updated': 1645569960,
#     'renting': 1,
#     'returning': 1,
#     'uid': '553'},
#    'free_bikes': 9,
#    'id': 'fc34cbf70e34346806c43b6579117bc0',
#    'latitude': 37.799676,
#    'longitude': -122.452599,
#    'name': 'Torney Ave at Lincoln Blvd',
#    'timestamp': '2022-02-23T03:54:22.512000Z'},
#   {'empty_slots': 5,
#    'extra': {'address': None,
#     'ebikes': 11,
#     'has_ebikes': True,
#     'last_updated': 1645584308,
#     'renting': 1,
#     'returning': 1,
#     'uid': '552'},
#    'free_bikes': 21,
#    'id': '8e8dc3a01762357b14e04515bd5c4ea0',
#    'latitude': 37.8017523,
#    'longitude': -122.456365,
#    'name': 'Anza Ave at Lincoln Blvd',
#    'timestamp': '2022-02-23T03:54:22.513000Z'},
#   {'empty_slots': 18,
#    'extra': {'address': None,
#     'ebikes': 4,
#     'has_ebikes': True,
#     'last_updated': 1645574931,
#     'renting': 1,
#     'returning': 1,
#     'uid': '501'},
#    'free_bikes': 5,
#    'id': 'df9c9c79952699cc041118a331ea9cc2',
#    'latitude': 37.72489268384971,
#    'longitude': -122.4432384967804,
#    'name': 'Balboa Park (San Jose Ave at Sgt. John V. Young Ln)',
#    'timestamp': '2022-02-23T03:54:23.195000Z'},
#   {'empty_slots': 17,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645583734,
#     'renting': 1,
#     'returning': 1,
#     'uid': '566'},
#    'free_bikes': 10,
#    'id': '5dc0d98ea835b4c9743d4e2cdd515dde',
#    'latitude': 37.726266,
#    'longitude': -122.479462,
#    'name': 'SFSU University Park North - West',
#    'timestamp': '2022-02-23T03:54:23.401000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 7,
#     'has_ebikes': True,
#     'last_updated': 1645581106,
#     'renting': 1,
#     'returning': 1,
#     'uid': '567'},
#    'free_bikes': 11,
#    'id': '97871d03b345e3aa1de1dbed3640b700',
#    'latitude': 37.725603,
#    'longitude': -122.476561,
#    'name': 'SFSU University Park North - East',
#    'timestamp': '2022-02-23T03:54:23.402000Z'},
#   {'empty_slots': 4,
#    'extra': {'address': None,
#     'ebikes': 5,
#     'has_ebikes': True,
#     'last_updated': 1645534588,
#     'renting': 1,
#     'returning': 1,
#     'uid': '565'},
#    'free_bikes': 15,
#    'id': 'e427fa5d07c952f21297dbd9c7693407',
#    'latitude': 37.723426,
#    'longitude': -122.455102,
#    'name': 'Brighton Ave at Ocean Ave',
#    'timestamp': '2022-02-23T03:54:23.399000Z'},
#   {'empty_slots': 23,
#    'extra': {'address': None,
#     'ebikes': 0,
#     'has_ebikes': True,
#     'last_updated': 1645556299,
#     'renting': 1,
#     'returning': 1,
#     'uid': '568'},
#    'free_bikes': 0,
#    'id': '1a71ef24deb93ea8024083bb3f0ed6c2',
#    'latitude': 37.7273951,
#    'longitude': -122.4354739,
#    'name': 'Alemany Blvd at Francis St',
#    'timestamp': '2022-02-23T03:54:23.392000Z'}]}

# %%
df_us_bikes = pd.concat(df_us)
df_us_bikes
# Out:
#                                               company  ... location.longitude
# 0                     [PBSC, Alta Bicycle Share, Inc]  ...        -106.837002
# 0               [Clean Energy Coalition, BCycle, LLC]  ...         -83.745360
# 0                                       [BCycle, LLC]  ...         -97.743550
# 0                 [Motivate International, Inc, PBSC]  ...         -85.309680
# 0   [Portland Bureau of Transportation (PBOT), Mot...  ...        -122.681079
# ..                                                ...  ...                ...
# 0                                     [Nextbike GmbH]  ...         -74.003500
# 0                                     [Nextbike GmbH]  ...         -74.014200
# 0                                     [Nextbike GmbH]  ...         -74.013500
# 0                                     [Nextbike GmbH]  ...         -74.052000
# 0                                      [Motivate LLC]  ...        -122.250000
#
# [64 rows x 10 columns]

# %%
stations = pd.concat(df_stations)
stations["empty_slots"].sum() + stations["free_bikes"].sum()
# Out:
# 130985.0

# %%
stations.to_csv('us_bike_stations.csv', index=False)

# %%
import numpy as np
stations['index'] = np.arange(len(stations))
stations = stations.set_index('index')
stations.head()
# Out:
#       empty_slots  free_bikes  ... extra.number  extra.slots
# index                          ...
# 0               5           6  ...          NaN          NaN
# 1               6           3  ...          NaN          NaN
# 2               6           1  ...          NaN          NaN
# 3               6           1  ...          NaN          NaN
# 4               7           0  ...          NaN          NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# # Question 3
#
# You have just finished touring Coit Tower in San Francisco, which is located at latitude 37.802747 and longitude -122.405861. Using your `DataFrame` from Question 2, find the nearest bike station with an available bike, based on taxicab distance (a.k.a. Manhattan distance).
#
# _Hint:_ You can check your answer using Google Maps!

# %%
from sklearn.metrics.pairwise import manhattan_distances
df_latlong = stations[["latitude", "longitude"]]
d = {'latitude': [37.802747], 'longitude': [-122.405861]}
df_coit = pd.DataFrame(data = d)
arr = manhattan_distances(df_latlong, df_coit)
nearest = arr.argmin().astype(int)
stations["name"][nearest]
# Out:
# 'The Embarcadero at Sansome St'

# %% [markdown]
# Submission Instructions
#
# - Copy this notebook to your own Drive, if you have not already.
# - Restart this notebook and run the cells from beginning to end.
#   - Go to Runtime > Restart and Run All.
# - Rename this notebook by clicking on "DATA 301 Lab 6A - YOUR NAMES HERE" at the very top of this page. Replace "YOUR NAMES HERE" with the first and last names of you (and your partners, for Phase 2).
# - Get the link to your notebook:
#   - Click on "Share" at the top-right.
#   - Change the settings to "Anyone with the link can view".
#   - Copy the sharing link into Canvas.
